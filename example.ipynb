# %%
import pandas as pd
df = pd.read_csv('4. Tenants_ Potential Buyers.csv')
df.head()
# Out:
#         start         end  \
# 0  2025-11-22  2025-11-22
# 1  2025-11-22  2025-11-22
# 2  2025-11-22  2025-11-22
# 3  2025-11-22  2025-11-22
# 4  2025-11-22  2025-11-22
#
#   Hello, My name is [Interviewer name] from Takwimu Research, a company that conducts market research studies. We are conducting a short survey to understand the property development landscape in Kenya. Your experience is incredibly valuable to us and we would like to get your feedback. This survey will take approximately 15-20 minutes to complete. Your responses will be kept confidential and will only be used for internal improvement purposes. May I request your consent?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   Demographics.     DEM 1: What is your gender (SELECT ONE)  \
# ...

# %%
df2 = pd.read_csv('5. Real Estate Agents.csv')
df2.head()
# Out:
#         start         end  \
# 0  02/12/2025  02/12/2025
# 1  02/12/2025  02/12/2025
# 2  02/12/2025  02/12/2025
# 3  02/12/2025  02/12/2025
# 4  02/12/2025  02/12/2025
#
#   Hello, My name is [Interviewer name] from Takwimu Research, a company that conducts market research studies. We are conducting a short survey to understand the property development landscape in Kenya. Your experience is incredibly valuable to us and we would like to get your feedback. This survey will take approximately 15-20 minutes to complete. Your responses will be kept confidential and will only be used for internal improvement purposes. May I request your consent?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
# ...

# %%
df.columns.tolist()
# Out:
# ['start',
#  'end',
#  'Hello, My name is [Interviewer name] from Takwimu Research, a company that conducts market research studies. We are conducting a short survey to understand the property development landscape in Kenya. Your experience is incredibly valuable to us and we would like to get your feedback. This survey will take approximately 15-20 minutes to complete. Your responses will be kept confidential and will only be used for internal improvement purposes. May I request your consent?',
#  'Demographics.     DEM 1: What is your gender (SELECT ONE)',
#  'DEM 2: What is your age (SELECT ONE)',
#  'DEM 3: What is your area of residence',
#  'DEM 4: What is your occupation (SELECT ONE)',
#  'DEM 5:  What is your specific expertise (specify profession), e.g Teacher, Farmer, etc.',
#  'DEM 6: What is your highest level of education (SELECT ONE)',
#  'DEM 7:  What is your average monthly household income (combined) (SELECT ONE)',
# ...

# %%
df2.columns.tolist()
# Out:
# ['start',
#  'end',
#  'Hello, My name is [Interviewer name] from Takwimu Research, a company that conducts market research studies. We are conducting a short survey to understand the property development landscape in Kenya. Your experience is incredibly valuable to us and we would like to get your feedback. This survey will take approximately 15-20 minutes to complete. Your responses will be kept confidential and will only be used for internal improvement purposes. May I request your consent?',
#  'How long have you worked in this position? (Must be more than 2 years)',
#  'D1. What are some of the most common property (residential, commercial, etc) INQUIRIES in the past 12 months? (MULTIPLE CHOICE)',
#  'D1. What are some of the most common property (residential, commercial, etc) INQUIRIES in the past 12 months? (MULTIPLE CHOICE)/Other',
# ...

# %%
import pandas as pd
df3 = pd.read_csv('3. Property Owners_ Investors (1).csv')
df3.columns.tolist()
# Out:
# ['start',
#  'end',
#  'Hello, My name is [Interviewer name] from Takwimu Research, a company that conducts market research studies. We are conducting a short survey to understand the property development landscape in Kenya. Your experience is incredibly valuable to us and we would like to get your feedback. This survey will take approximately 15-20 minutes to complete. Your responses will be kept confidential and will only be used for internal improvement purposes. May I request your consent?',
#  'Demographics.     DEM 1: What is your gender (SELECT ONE)',
#  'DEM 2: What is your age (SELECT ONE)',
#  'DEM 3: What is your area of residence',
#  'DEM 4: What is your occupation (SELECT ONE)',
#  'DEM 5:  What is your specific expertise (specify profession), e.g Teacher, Farmer, etc.',
#  'DEM 6: What is your highest level of education (SELECT ONE)',
#  'DEM 7:  What is your average monthly household income (combined) (SELECT ONE)',
# ...

# %%
df4 = pd.read_csv('2. Property Developers.csv')
df4.columns.tolist()
# Out:
# ['start',
#  'end',
#  'Hello, My name is [Interviewer name] from Takwimu Research, a company that conducts market research studies. We are conducting a short survey to understand the property development landscape in Kenya. Your experience is incredibly valuable to us and we would like to get your feedback. This survey will take approximately 15-20 minutes to complete. Your responses will be kept confidential and will only be used for internal improvement purposes. May I request your consent?',
#  'Name of Company',
#  'Name of Respondent (Optional)',
#  'Department (Preferably in Finance, Sales or Engineering departments)',
#  'How long have you worked in this position? (Must be more than 2 years)',
#  'D1. What are some of the most common property (residential, commercial, etc) INQUIRIES in the past 12 months? (MULTIPLE CHOICE)',
# ...

# %%
df4 = pd.read_csv('1. Banks Financial Institutions.csv')
df4.columns.tolist()
# Out:
# ['start',
#  'end',
#  'Hello, My name is [Interviewer name] from Takwimu Research, a company that conducts market research studies. We are conducting a short survey to understand the property development landscape in Kenya. Your experience is incredibly valuable to us and we would like to get your feedback. This survey will take approximately 15-20 minutes to complete. Your responses will be kept confidential and will only be used for internal improvement purposes. May I request your consent?',
#  'Name of Company/ Institution',
#  'Select category',
#  'Name of Respondent',
#  'Department (Asset Financing, Investment Banking, Risk, Corporate, etc)',
#  'Job Title',
#  'How long have you worked in this position? (Must be more than 2 years)',
#  'C1.  Which property development projects (residential, commercial, etc) received the most INQUIRIES  about FINANCING in the past 12 months? MULTIPLE MENTIONS',
# ...
