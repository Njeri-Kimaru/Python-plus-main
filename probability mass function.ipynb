# %% [markdown]
# ##### imports
#     import pandas as pd
#     import numpy as np
#     import seaborn as sns
#     import scipy.stats as stats
#     import matplotlib.pyplot as plt
#
# ##### Z-SCORE
#     x = 70
#     mu = 50
#     sd = 10
#
#     z = (x-mu)/sd
#     z
#
# ##### distplot plotting
#
#     import numpy as np
#     import seaborn as sns
#     mean1, sd1 =5,3 # mean1
#     mean2, sd2 = 10,2 #mean2
#     d1 = np.random.normal(mean1, sd1, 1000)
#     d2 = np.random.normal(mean2, sd2, 1000)
#     sns.distplot(d1);
#     sns.distplot(d2);
#
# ##### Stardardizing and visualizing distributions
#     sns.distplot([(x - d1.mean())/d1.std() for x in d1]);
#     sns.distplot([(x - d2.mean())/d2.std() for x in d2]);

# %% [markdown]
# # WEDNESDAY 24TH SEP,2025
# ## STANDARDIZATION

# %% [markdown]
# ### Z-CODE
# - z score = x((variable) - mu(mean)) / std deviation

# %%
# z score = x((variable) - u(mean)) / std deviation
x = 70
mu = 50
sd = 10

z = (x-mu)/sd
z
# Out:
# 2.0

# %%
mean_iq = 100
std_deviation = 15
x_iq = 120

z_iq = (x_iq-mean_iq)/std_deviation
z_iq
# Out:
# 1.3333333333333333

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
import numpy as np
import seaborn as sns
mean1, sd1 =5,3 # mean1
mean2, sd2 = 10,2 #mean2
d1 = np.random.normal(mean1, sd1, 1000)
d2 = np.random.normal(mean2, sd2, 1000)
sns.distplot(d1);
sns.distplot(d2);
# Out:
# C:\Users\inkan\AppData\Local\Temp\ipykernel_34184\2682184959.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d1);
# C:\Users\inkan\AppData\Local\Temp\ipykernel_34184\2682184959.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d2);

# %%
sns.displot([(x - d1.mean())/d1.std() for x in d1])
sns.distplot([(x - d1.mean())/d1.std() for x in d2])

# %%
# Stardardizing and visualizing distributions

sns.distplot([(x - d1.mean())/d1.std() for x in d1]);
sns.distplot([(x - d2.mean())/d2.std() for x in d2]);
# Out:
# C:\Users\inkan\AppData\Local\Temp\ipykernel_34184\4206954641.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([(x - d1.mean())/d1.std() for x in d1]);
# C:\Users\inkan\AppData\Local\Temp\ipykernel_34184\4206954641.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ### SKEWNESS AND KURTOSIS
